# %% [markdown]
# <a href="https://colab.research.google.com/github/SaraRebecka/atividades-python/blob/main/atividade01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Atividade 01-Introdução ao Python

# %%
print("Olá, mundo!")
print("Curso Técnico em Informática")
# Out:
# Olá, mundo!
# Curso Técnico em Informática

# %%
disciplina = input("Digite o nome da disciplina:")
conteudo = input("Digite o conteúdo estudado:")
atividade = input("Digite o número da atividade:")
print("\n---Informaçoes da atividade---")
print("Disciplina:", disciplina)
print("Conteúdo:", conteudo)
print("Atividade:", atividade)
# Out:
# Digite o nome da disciplina:Matemática
# Digite o conteúdo estudado:Função Modular
# Digite o número da atividade:1
#
# ---Informaçoes da atividade---
# Disciplina: Matemática
# Conteúdo: Função Modular
# Atividade: 1
